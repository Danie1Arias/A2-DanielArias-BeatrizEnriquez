# %%
import matplotlib.pyplot as plt
from GeneticAlgorithm import GeneticAlgorithm
from Utils import plot_gantt_chart

data = [
    [4, 88, 8, 68, 6, 94, 5, 99, 1, 67],
    [2, 89, 9, 77, 7, 99, 0, 86, 3, 92],
    [5, 72, 3, 50, 6, 69, 4, 75, 2, 94],
    [8, 66, 0, 92, 1, 82, 7, 94, 9, 63],
    [9, 83, 8, 61, 0, 83, 1, 65, 6, 64],
    [5, 85, 7, 78, 4, 85, 2, 55, 3, 77],
    [7, 94, 2, 68, 1, 61, 4, 99, 3, 54],
    [6, 75, 5, 66, 0, 76, 9, 63, 8, 67],
    [3, 69, 4, 88, 9, 82, 8, 95, 0, 99],
    [2, 67, 6, 95, 5, 68, 7, 67, 1, 86]
]

# Example data
data = [
    [0, 3, 1, 2, 2, 2],
    [0, 2, 2, 1, 1, 4],
    [1, 4, 2, 3]
]

# Hyperparameters
population_size = 3
generations = 20
mutation_rate = 0.1
elitism = 0.1

# Initialize the Genetic Algorithm
ga = GeneticAlgorithm(data, population_size=population_size, generations=generations, mutation_rate=mutation_rate, elitism=elitism)

# Run the genetic algorithm
best_solution, best_makespan, evolution, decoded_solution = ga.run()

print("Best Solution (decoded):", decoded_solution)
print("Best Makespan:", best_makespan)

# Plot the evolution of the makespan
plt.plot(evolution, label="Best Makespan")
plt.xlabel("Generation")
plt.ylabel("Makespan")
plt.title("Evolution of Makespan Over Generations")
plt.legend()
plt.show()

# Plot the Gantt chart with the updated function
plot_gantt_chart(decoded_solution, ga.jobs)
# Out:
# Generation 1: Best Makespan = 10
# Generation 2: Best Makespan = 10
# Generation 3: Best Makespan = 10
# Generation 4: Best Makespan = 10
# Generation 5: Best Makespan = 10
# Generation 6: Best Makespan = 10
# Generation 7: Best Makespan = 10
# Generation 8: Best Makespan = 10
# Generation 9: Best Makespan = 10
# Generation 10: Best Makespan = 10
# Generation 11: Best Makespan = 10
# Generation 12: Best Makespan = 10
# Generation 13: Best Makespan = 10
# Generation 14: Best Makespan = 10
# Generation 15: Best Makespan = 10
# Generation 16: Best Makespan = 10
# Generation 17: Best Makespan = 10
# Generation 18: Best Makespan = 10
# Generation 19: Best Makespan = 10
# Generation 20: Best Makespan = 10
# Best Solution (decoded): [(1, 1, 4), (2, 2, 3), (1, 2, 1), (2, 1, 4), (1, 0, 2), (0, 2, 2), (0, 1, 2), (0, 0, 3)]
# Best Makespan: 10
# Task Details:
# Machine 0: Job 1, Task 1, Start Time: 0, Duration: 2
# Machine 0: Job 0, Task 2, Start Time: 2, Duration: 3
# Machine 1: Job 1, Task 1, Start Time: 0, Duration: 4
# Machine 1: Job 2, Task 2, Start Time: 4, Duration: 4
# Machine 1: Job 0, Task 3, Start Time: 8, Duration: 2
# Machine 2: Job 2, Task 1, Start Time: 0, Duration: 3
# Machine 2: Job 1, Task 2, Start Time: 3, Duration: 1
# Machine 2: Job 0, Task 3, Start Time: 4, Duration: 2
